# %% [markdown]
# <a href="https://colab.research.google.com/github/Qiu-LingYan/TripBot/blob/main/heyue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 安装依赖
# !pip install torch numpy pandas scikit-learn streamlit plotly websocket-client requests python-dotenv

# %%
# 运行监控面板
# !python main.py --mode dashboard

# %%
# 运行模拟交易
# !python main.py --mode simulate --model models_saved/best_model.pt
# Out:
# 2026-02-15 02:53:12,553 - root - INFO - 使用设备: cpu
# 2026-02-15 02:53:13,964 - root - INFO - 交易系统初始化完成
# Traceback (most recent call last):
#   File "/content/main.py", line 2916, in <module>
#     main()
#   File "/content/main.py", line 2899, in main
#     system.agent.load_checkpoint(args.model)
#   File "/content/main.py", line 1371, in load_checkpoint
#     checkpoint = torch.load(path, map_location=self.device)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1484, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 759, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 740, in __init__
#     super().__init__(open(name, mode))
# ...

# %%
# 运行回测
# !python main.py --mode backtest --start 2023-01-01 --end 2023-12-31 --model models_saved/best_model.pt

# %%
# 训练模型
# !python main.py --mode train --episodes 5000
